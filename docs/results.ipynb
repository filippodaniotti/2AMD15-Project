# %%
import matplotlib.pyplot as plt

# %%
def q2_res():
    t_values = [str(t) for t in [20, 50, 310, 360, 410]]
    counts = [2, 4, 4, 10, 10]
    
    plt.bar(t_values, counts)
    plt.suptitle("Results for question 2")
    plt.xlabel("τ values")
    plt.ylabel("Counts")
    plt.show()

q2_res()
